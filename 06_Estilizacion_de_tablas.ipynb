# %% [markdown]
# <a href="https://colab.research.google.com/github/Idguerrero333/NOTEBOOKPYTHONINTERACTIVE/blob/main/06_Estilizacion_de_tablas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ruta = 'https://gist.githubusercontent.com/ahcamachod/d2efadda3f3833d65da750c64705ac42/raw/80aef6f3bad210d34b67ed85565f039a30e2d9e0/ventas.csv'

# %% [markdown]
# # **Data Visualization: Estilizando tablas con python**

# %% [markdown]
# ## **Extracción y preparación de los datos**

# %%
#!pip install pandas==2.0.0

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
ventas = pd.read_csv(ruta, sep='#')

# %%
ventas.head()
# Out:
#   fecha_pedido fecha_envio        modo_envio    nombre_cliente  \
# 0   2018-11-09  2018-11-12         Económica  Gaspar Fernández
# 1   2018-11-09  2018-11-12         Económica  Gaspar Fernández
# 2   2018-06-13  2018-06-17         Económica   Matías González
# 3   2017-10-12  2017-10-19  Entrega estándar    Lucas González
# 4   2017-10-12  2017-10-19  Entrega estándar    Lucas González
#
#   segmento_cliente           ciudad     provincia        region  \
# 0              B2C  Lomas de Zamora  Buenos Aires  Buenos Aires
# 1              B2C  Lomas de Zamora  Buenos Aires  Buenos Aires
# 2              B2B          Córdoba       Córdoba       Central
# 3              B2C        Gualeguay    Entre Ríos       Litoral
# 4              B2C        Gualeguay    Entre Ríos       Litoral
#
#                  departamento                tipo_producto  precio_base  \
# 0  Materiales de construcción                   Fontanería       409.70
# 1  Materiales de construcción                 Herramientas       705.10
# 2     Jardinería y paisajismo                     Semillas        19.02
# 3  Materiales de construcción  Materiales de revestimiento       781.38
# 4     Jardinería y paisajismo                      Macetas        35.88
#
#    precio_unit_sin_descuento  descuento  precio_unit_venta  cantidad   ventas  \
# 0                     445.33      0.000             445.33         2   890.66
# 1                     829.53      0.000             829.53         3  2488.59
# 2                      24.86      0.000              24.86         2    49.72
# 3                     840.19      0.225             651.15         5  3255.75
# 4                      42.24      0.100              38.02         2    76.04
#
#    ganancia
# 0     71.26
# 1    373.29
# 2     11.68
# 3   -651.15
# 4      4.28

# %%
ventas = ventas[['fecha_pedido','modo_envio',	'nombre_cliente',	'segmento_cliente',	'ciudad',	'provincia',	'region',	'departamento',	'tipo_producto',	'cantidad','ventas',	'ganancia']]
ventas.head(2)
# Out:
#   fecha_pedido modo_envio    nombre_cliente segmento_cliente           ciudad  \
# 0   2018-11-09  Económica  Gaspar Fernández              B2C  Lomas de Zamora
# 1   2018-11-09  Económica  Gaspar Fernández              B2C  Lomas de Zamora
#
#       provincia        region                departamento tipo_producto  \
# 0  Buenos Aires  Buenos Aires  Materiales de construcción    Fontanería
# 1  Buenos Aires  Buenos Aires  Materiales de construcción  Herramientas
#
#    cantidad   ventas  ganancia
# 0         2   890.66     71.26
# 1         3  2488.59    373.29

# %%
ventas.shape
# Out:
# (8940, 12)

# %%
ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8940 entries, 0 to 8939
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fecha_pedido      8940 non-null   object
#  1   modo_envio        8940 non-null   object
#  2   nombre_cliente    8940 non-null   object
#  3   segmento_cliente  8940 non-null   object
#  4   ciudad            8940 non-null   object
#  5   provincia         8940 non-null   object
#  6   region            8940 non-null   object
#  7   departamento      8940 non-null   object
#  8   tipo_producto     8940 non-null   object
#  9   cantidad          8940 non-null   int64
#  10  ventas            8940 non-null   float64
#  11  ganancia          8940 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 838.3+ KB

# %%
ventas['fecha_pedido'] = pd.to_datetime(ventas['fecha_pedido'],format='%Y-%m-%d')
ventas.head(2)
# Out:
#   fecha_pedido modo_envio    nombre_cliente segmento_cliente           ciudad  \
# 0   2018-11-09  Económica  Gaspar Fernández              B2C  Lomas de Zamora
# 1   2018-11-09  Económica  Gaspar Fernández              B2C  Lomas de Zamora
#
#       provincia        region                departamento tipo_producto  \
# 0  Buenos Aires  Buenos Aires  Materiales de construcción    Fontanería
# 1  Buenos Aires  Buenos Aires  Materiales de construcción  Herramientas
#
#    cantidad   ventas  ganancia
# 0         2   890.66     71.26
# 1         3  2488.59    373.29

# %%
ventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8940 entries, 0 to 8939
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fecha_pedido      8940 non-null   datetime64[ns]
#  1   modo_envio        8940 non-null   object
#  2   nombre_cliente    8940 non-null   object
#  3   segmento_cliente  8940 non-null   object
#  4   ciudad            8940 non-null   object
#  5   provincia         8940 non-null   object
#  6   region            8940 non-null   object
#  7   departamento      8940 non-null   object
#  8   tipo_producto     8940 non-null   object
#  9   cantidad          8940 non-null   int64
#  10  ventas            8940 non-null   float64
#  11  ganancia          8940 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(8)
# memory usage: 838.3+ KB

# %% [markdown]
# ## Misión 1: Equipo de Ventas
#
# Necesitamos construir una visualización para indicar los **10 principales clientes por total de ventas**.
#
# Con ello, el equipo de ventas puede pensar en estrategias para mantener a estos clientes comprando en nuestra tienda.

# %%
clientes = ventas.groupby(['nombre_cliente'])['ventas'].sum().nlargest(10).copy()
clientes = clientes.reset_index()
clientes
# Out:
#       nombre_cliente    ventas
# 0    Víctor Carrasco  73370.61
# 1        Brisa Rojas  68868.11
# 2       Mateo Vargas  62749.75
# 3      Vicente Rojas  59544.11
# 4        Laura Rojas  51398.87
# 5         Lucía Díaz  48178.99
# 6   Cristina Barrios  47610.80
# 7  Alejandro Sánchez  43769.25
# 8      Pamela Huerta  42354.19
# 9     Carlos Sánchez  41238.81

# %%
##dic = {'nombre_cliente':Clientes, 'ventas':'Ventas'}
##clientes = clientes.rename(columns=dic)

clientes.columns = ['Clientes', 'Ventas']
clientes['Ranking'] = clientes.index + 1
clientes.set_index('Ranking', inplace=True)
clientes
# Out:
#                   Clientes    Ventas
# Ranking
# 1          Víctor Carrasco  73370.61
# 2              Brisa Rojas  68868.11
# 3             Mateo Vargas  62749.75
# 4            Vicente Rojas  59544.11
# 5              Laura Rojas  51398.87
# 6               Lucía Díaz  48178.99
# 7         Cristina Barrios  47610.80
# 8        Alejandro Sánchez  43769.25
# 9            Pamela Huerta  42354.19
# 10          Carlos Sánchez  41238.81

# %%
estilo = clientes.style
estilo
# Out:
# <style type="text/css">
# </style>
# <table id="T_dc7cf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc7cf_level0_col0" class="col_heading level0 col0" >Clientes</th>
#       <th id="T_dc7cf_level0_col1" class="col_heading level0 col1" >Ventas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranking</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc7cf_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_dc7cf_row0_col0" class="data row0 col0" >Víctor Carrasco</td>
#       <td id="T_dc7cf_row0_col1" class="data row0 col1" >73370.610000</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_dc7cf_row1_col0" class="data row1 col0" >Brisa Rojas</td>
#       <td id="T_dc7cf_row1_col1" class="data row1 col1" >68868.110000</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_dc7cf_row2_col0" class="data row2 col0" >Mateo Vargas</td>
#       <td id="T_dc7cf_row2_col1" class="data row2 col1" >62749.750000</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_dc7cf_row3_col0" class="data row3 col0" >Vicente Rojas</td>
#       <td id="T_dc7cf_row3_col1" class="data row3 col1" >59544.110000</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_dc7cf_row4_col0" class="data row4 col0" >Laura Rojas</td>
#       <td id="T_dc7cf_row4_col1" class="data row4 col1" >51398.870000</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_dc7cf_row5_col0" class="data row5 col0" >Lucía Díaz</td>
#       <td id="T_dc7cf_row5_col1" class="data row5 col1" >48178.990000</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_dc7cf_row6_col0" class="data row6 col0" >Cristina Barrios</td>
#       <td id="T_dc7cf_row6_col1" class="data row6 col1" >47610.800000</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_dc7cf_row7_col0" class="data row7 col0" >Alejandro Sánchez</td>
#       <td id="T_dc7cf_row7_col1" class="data row7 col1" >43769.250000</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_dc7cf_row8_col0" class="data row8 col0" >Pamela Huerta</td>
#       <td id="T_dc7cf_row8_col1" class="data row8 col1" >42354.190000</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_dc7cf_row9_col0" class="data row9 col0" >Carlos Sánchez</td>
#       <td id="T_dc7cf_row9_col1" class="data row9 col1" >41238.810000</td>
#     </tr>
#   </tbody>
# </table>

# %%
estilo.format({'Ventas':'{:,.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_dc7cf" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc7cf_level0_col0" class="col_heading level0 col0" >Clientes</th>
#       <th id="T_dc7cf_level0_col1" class="col_heading level0 col1" >Ventas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Ranking</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc7cf_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_dc7cf_row0_col0" class="data row0 col0" >Víctor Carrasco</td>
#       <td id="T_dc7cf_row0_col1" class="data row0 col1" >73,370.61</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_dc7cf_row1_col0" class="data row1 col0" >Brisa Rojas</td>
#       <td id="T_dc7cf_row1_col1" class="data row1 col1" >68,868.11</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_dc7cf_row2_col0" class="data row2 col0" >Mateo Vargas</td>
#       <td id="T_dc7cf_row2_col1" class="data row2 col1" >62,749.75</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_dc7cf_row3_col0" class="data row3 col0" >Vicente Rojas</td>
#       <td id="T_dc7cf_row3_col1" class="data row3 col1" >59,544.11</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_dc7cf_row4_col0" class="data row4 col0" >Laura Rojas</td>
#       <td id="T_dc7cf_row4_col1" class="data row4 col1" >51,398.87</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_dc7cf_row5_col0" class="data row5 col0" >Lucía Díaz</td>
#       <td id="T_dc7cf_row5_col1" class="data row5 col1" >48,178.99</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_dc7cf_row6_col0" class="data row6 col0" >Cristina Barrios</td>
#       <td id="T_dc7cf_row6_col1" class="data row6 col1" >47,610.80</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_dc7cf_row7_col0" class="data row7 col0" >Alejandro Sánchez</td>
#       <td id="T_dc7cf_row7_col1" class="data row7 col1" >43,769.25</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_dc7cf_row8_col0" class="data row8 col0" >Pamela Huerta</td>
#       <td id="T_dc7cf_row8_col1" class="data row8 col1" >42,354.19</td>
#     </tr>
#     <tr>
#       <th id="T_dc7cf_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_dc7cf_row9_col0" class="data row9 col0" >Carlos Sánchez</td>
#       <td id="T_dc7cf_row9_col1" class="data row9 col1" >41,238.81</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Misión 2: Equipo Comercial
#
# Necesitamos construir una visualización que permita asociar el **total de ganancias en ventas y el total de lucros por tipo de producto**.
#
# Ello permitirá que el equipo comercial pueda enfocarse en estrategias para apalancar los ingresos que se reciben con cada tipo de producto vendido en la tienda.

# %%
ganancias_ventas = ventas.groupby(['tipo_producto'])[['ventas','ganancia']].sum()##[[]]creando dataframe
ganancias_ventas
# Out:
#                                  ventas  ganancia
# tipo_producto
# Brotes                          8811.32   1381.42
# Decoración de jardín           82680.08   9939.43
# Equipos de limpieza           542304.58   8724.39
# Fertilizantes                  53144.74  11254.88
# Fontanería                    373223.88  -5622.34
# Herramientas                  995158.41  41020.34
# Herramientas automotrices     502109.29  63330.22
# Herramientas de jardinería    648879.72  53202.88
# Iluminación                   275229.53  20264.54
# Macetas                       696044.18  33941.85
# Materiales de paisajismo      150552.49  -1912.37
# Materiales de revestimiento   629656.36 -28869.01
# Muebles de exterior           328932.27  26784.59
# Neumáticos                   1022428.97  67460.05
# Pesticidas                    244956.04  53343.89
# Piezas de repuesto            486907.94  91148.67
# Semillas                       39979.75   8865.09

# %%
ganancias_ventas.index.name = 'tipo de producto'
ganancias_ventas
# Out:
#                                  ventas  ganancia
# tipo de producto
# Brotes                          8811.32   1381.42
# Decoración de jardín           82680.08   9939.43
# Equipos de limpieza           542304.58   8724.39
# Fertilizantes                  53144.74  11254.88
# Fontanería                    373223.88  -5622.34
# Herramientas                  995158.41  41020.34
# Herramientas automotrices     502109.29  63330.22
# Herramientas de jardinería    648879.72  53202.88
# Iluminación                   275229.53  20264.54
# Macetas                       696044.18  33941.85
# Materiales de paisajismo      150552.49  -1912.37
# Materiales de revestimiento   629656.36 -28869.01
# Muebles de exterior           328932.27  26784.59
# Neumáticos                   1022428.97  67460.05
# Pesticidas                    244956.04  53343.89
# Piezas de repuesto            486907.94  91148.67
# Semillas                       39979.75   8865.09

# %%
estilo_producto = ganancias_ventas.style
estilo_producto
# Out:
# <style type="text/css">
# </style>
# <table id="T_a9207" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9207_level0_col0" class="col_heading level0 col0" >ventas</th>
#       <th id="T_a9207_level0_col1" class="col_heading level0 col1" >ganancia</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo de producto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9207_level0_row0" class="row_heading level0 row0" >Brotes</th>
#       <td id="T_a9207_row0_col0" class="data row0 col0" >8811.320000</td>
#       <td id="T_a9207_row0_col1" class="data row0 col1" >1381.420000</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row1" class="row_heading level0 row1" >Decoración de jardín</th>
#       <td id="T_a9207_row1_col0" class="data row1 col0" >82680.080000</td>
#       <td id="T_a9207_row1_col1" class="data row1 col1" >9939.430000</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row2" class="row_heading level0 row2" >Equipos de limpieza</th>
#       <td id="T_a9207_row2_col0" class="data row2 col0" >542304.580000</td>
#       <td id="T_a9207_row2_col1" class="data row2 col1" >8724.390000</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row3" class="row_heading level0 row3" >Fertilizantes</th>
#       <td id="T_a9207_row3_col0" class="data row3 col0" >53144.740000</td>
#       <td id="T_a9207_row3_col1" class="data row3 col1" >11254.880000</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row4" class="row_heading level0 row4" >Fontanería</th>
#       <td id="T_a9207_row4_col0" class="data row4 col0" >373223.880000</td>
#       <td id="T_a9207_row4_col1" class="data row4 col1" >-5622.340000</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row5" class="row_heading level0 row5" >Herramientas</th>
#       <td id="T_a9207_row5_col0" class="data row5 col0" >995158.410000</td>
#       <td id="T_a9207_row5_col1" class="data row5 col1" >41020.340000</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row6" class="row_heading level0 row6" >Herramientas automotrices</th>
#       <td id="T_a9207_row6_col0" class="data row6 col0" >502109.290000</td>
#       <td id="T_a9207_row6_col1" class="data row6 col1" >63330.220000</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row7" class="row_heading level0 row7" >Herramientas de jardinería</th>
#       <td id="T_a9207_row7_col0" class="data row7 col0" >648879.720000</td>
#       <td id="T_a9207_row7_col1" class="data row7 col1" >53202.880000</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row8" class="row_heading level0 row8" >Iluminación</th>
#       <td id="T_a9207_row8_col0" class="data row8 col0" >275229.530000</td>
#       <td id="T_a9207_row8_col1" class="data row8 col1" >20264.540000</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row9" class="row_heading level0 row9" >Macetas</th>
#       <td id="T_a9207_row9_col0" class="data row9 col0" >696044.180000</td>
#       <td id="T_a9207_row9_col1" class="data row9 col1" >33941.850000</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row10" class="row_heading level0 row10" >Materiales de paisajismo</th>
#       <td id="T_a9207_row10_col0" class="data row10 col0" >150552.490000</td>
#       <td id="T_a9207_row10_col1" class="data row10 col1" >-1912.370000</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row11" class="row_heading level0 row11" >Materiales de revestimiento</th>
#       <td id="T_a9207_row11_col0" class="data row11 col0" >629656.360000</td>
#       <td id="T_a9207_row11_col1" class="data row11 col1" >-28869.010000</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row12" class="row_heading level0 row12" >Muebles de exterior</th>
#       <td id="T_a9207_row12_col0" class="data row12 col0" >328932.270000</td>
#       <td id="T_a9207_row12_col1" class="data row12 col1" >26784.590000</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row13" class="row_heading level0 row13" >Neumáticos</th>
#       <td id="T_a9207_row13_col0" class="data row13 col0" >1022428.970000</td>
#       <td id="T_a9207_row13_col1" class="data row13 col1" >67460.050000</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row14" class="row_heading level0 row14" >Pesticidas</th>
#       <td id="T_a9207_row14_col0" class="data row14 col0" >244956.040000</td>
#       <td id="T_a9207_row14_col1" class="data row14 col1" >53343.890000</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row15" class="row_heading level0 row15" >Piezas de repuesto</th>
#       <td id="T_a9207_row15_col0" class="data row15 col0" >486907.940000</td>
#       <td id="T_a9207_row15_col1" class="data row15 col1" >91148.670000</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row16" class="row_heading level0 row16" >Semillas</th>
#       <td id="T_a9207_row16_col0" class="data row16 col0" >39979.750000</td>
#       <td id="T_a9207_row16_col1" class="data row16 col1" >8865.090000</td>
#     </tr>
#   </tbody>
# </table>

# %%
estilo_producto.format({'ventas':'USD {:,.2f}', 'ganancia':'USD {:,.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_a9207" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9207_level0_col0" class="col_heading level0 col0" >ventas</th>
#       <th id="T_a9207_level0_col1" class="col_heading level0 col1" >ganancia</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo de producto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9207_level0_row0" class="row_heading level0 row0" >Brotes</th>
#       <td id="T_a9207_row0_col0" class="data row0 col0" >USD 8,811.32</td>
#       <td id="T_a9207_row0_col1" class="data row0 col1" >USD 1,381.42</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row1" class="row_heading level0 row1" >Decoración de jardín</th>
#       <td id="T_a9207_row1_col0" class="data row1 col0" >USD 82,680.08</td>
#       <td id="T_a9207_row1_col1" class="data row1 col1" >USD 9,939.43</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row2" class="row_heading level0 row2" >Equipos de limpieza</th>
#       <td id="T_a9207_row2_col0" class="data row2 col0" >USD 542,304.58</td>
#       <td id="T_a9207_row2_col1" class="data row2 col1" >USD 8,724.39</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row3" class="row_heading level0 row3" >Fertilizantes</th>
#       <td id="T_a9207_row3_col0" class="data row3 col0" >USD 53,144.74</td>
#       <td id="T_a9207_row3_col1" class="data row3 col1" >USD 11,254.88</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row4" class="row_heading level0 row4" >Fontanería</th>
#       <td id="T_a9207_row4_col0" class="data row4 col0" >USD 373,223.88</td>
#       <td id="T_a9207_row4_col1" class="data row4 col1" >USD -5,622.34</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row5" class="row_heading level0 row5" >Herramientas</th>
#       <td id="T_a9207_row5_col0" class="data row5 col0" >USD 995,158.41</td>
#       <td id="T_a9207_row5_col1" class="data row5 col1" >USD 41,020.34</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row6" class="row_heading level0 row6" >Herramientas automotrices</th>
#       <td id="T_a9207_row6_col0" class="data row6 col0" >USD 502,109.29</td>
#       <td id="T_a9207_row6_col1" class="data row6 col1" >USD 63,330.22</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row7" class="row_heading level0 row7" >Herramientas de jardinería</th>
#       <td id="T_a9207_row7_col0" class="data row7 col0" >USD 648,879.72</td>
#       <td id="T_a9207_row7_col1" class="data row7 col1" >USD 53,202.88</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row8" class="row_heading level0 row8" >Iluminación</th>
#       <td id="T_a9207_row8_col0" class="data row8 col0" >USD 275,229.53</td>
#       <td id="T_a9207_row8_col1" class="data row8 col1" >USD 20,264.54</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row9" class="row_heading level0 row9" >Macetas</th>
#       <td id="T_a9207_row9_col0" class="data row9 col0" >USD 696,044.18</td>
#       <td id="T_a9207_row9_col1" class="data row9 col1" >USD 33,941.85</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row10" class="row_heading level0 row10" >Materiales de paisajismo</th>
#       <td id="T_a9207_row10_col0" class="data row10 col0" >USD 150,552.49</td>
#       <td id="T_a9207_row10_col1" class="data row10 col1" >USD -1,912.37</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row11" class="row_heading level0 row11" >Materiales de revestimiento</th>
#       <td id="T_a9207_row11_col0" class="data row11 col0" >USD 629,656.36</td>
#       <td id="T_a9207_row11_col1" class="data row11 col1" >USD -28,869.01</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row12" class="row_heading level0 row12" >Muebles de exterior</th>
#       <td id="T_a9207_row12_col0" class="data row12 col0" >USD 328,932.27</td>
#       <td id="T_a9207_row12_col1" class="data row12 col1" >USD 26,784.59</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row13" class="row_heading level0 row13" >Neumáticos</th>
#       <td id="T_a9207_row13_col0" class="data row13 col0" >USD 1,022,428.97</td>
#       <td id="T_a9207_row13_col1" class="data row13 col1" >USD 67,460.05</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row14" class="row_heading level0 row14" >Pesticidas</th>
#       <td id="T_a9207_row14_col0" class="data row14 col0" >USD 244,956.04</td>
#       <td id="T_a9207_row14_col1" class="data row14 col1" >USD 53,343.89</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row15" class="row_heading level0 row15" >Piezas de repuesto</th>
#       <td id="T_a9207_row15_col0" class="data row15 col0" >USD 486,907.94</td>
#       <td id="T_a9207_row15_col1" class="data row15 col1" >USD 91,148.67</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row16" class="row_heading level0 row16" >Semillas</th>
#       <td id="T_a9207_row16_col0" class="data row16 col0" >USD 39,979.75</td>
#       <td id="T_a9207_row16_col1" class="data row16 col1" >USD 8,865.09</td>
#     </tr>
#   </tbody>
# </table>

# %%
estilo_producto = estilo_producto.format('USD {:,.2f}').highlight_max(color='lightgreen').highlight_min(color='pink')
estilo_producto
# Out:
# <style type="text/css">
# #T_a9207_row0_col0, #T_a9207_row11_col1 {
#   background-color: pink;
# }
# #T_a9207_row13_col0, #T_a9207_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a9207" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9207_level0_col0" class="col_heading level0 col0" >ventas</th>
#       <th id="T_a9207_level0_col1" class="col_heading level0 col1" >ganancia</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo de producto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9207_level0_row0" class="row_heading level0 row0" >Brotes</th>
#       <td id="T_a9207_row0_col0" class="data row0 col0" >USD 8,811.32</td>
#       <td id="T_a9207_row0_col1" class="data row0 col1" >USD 1,381.42</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row1" class="row_heading level0 row1" >Decoración de jardín</th>
#       <td id="T_a9207_row1_col0" class="data row1 col0" >USD 82,680.08</td>
#       <td id="T_a9207_row1_col1" class="data row1 col1" >USD 9,939.43</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row2" class="row_heading level0 row2" >Equipos de limpieza</th>
#       <td id="T_a9207_row2_col0" class="data row2 col0" >USD 542,304.58</td>
#       <td id="T_a9207_row2_col1" class="data row2 col1" >USD 8,724.39</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row3" class="row_heading level0 row3" >Fertilizantes</th>
#       <td id="T_a9207_row3_col0" class="data row3 col0" >USD 53,144.74</td>
#       <td id="T_a9207_row3_col1" class="data row3 col1" >USD 11,254.88</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row4" class="row_heading level0 row4" >Fontanería</th>
#       <td id="T_a9207_row4_col0" class="data row4 col0" >USD 373,223.88</td>
#       <td id="T_a9207_row4_col1" class="data row4 col1" >USD -5,622.34</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row5" class="row_heading level0 row5" >Herramientas</th>
#       <td id="T_a9207_row5_col0" class="data row5 col0" >USD 995,158.41</td>
#       <td id="T_a9207_row5_col1" class="data row5 col1" >USD 41,020.34</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row6" class="row_heading level0 row6" >Herramientas automotrices</th>
#       <td id="T_a9207_row6_col0" class="data row6 col0" >USD 502,109.29</td>
#       <td id="T_a9207_row6_col1" class="data row6 col1" >USD 63,330.22</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row7" class="row_heading level0 row7" >Herramientas de jardinería</th>
#       <td id="T_a9207_row7_col0" class="data row7 col0" >USD 648,879.72</td>
#       <td id="T_a9207_row7_col1" class="data row7 col1" >USD 53,202.88</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row8" class="row_heading level0 row8" >Iluminación</th>
#       <td id="T_a9207_row8_col0" class="data row8 col0" >USD 275,229.53</td>
#       <td id="T_a9207_row8_col1" class="data row8 col1" >USD 20,264.54</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row9" class="row_heading level0 row9" >Macetas</th>
#       <td id="T_a9207_row9_col0" class="data row9 col0" >USD 696,044.18</td>
#       <td id="T_a9207_row9_col1" class="data row9 col1" >USD 33,941.85</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row10" class="row_heading level0 row10" >Materiales de paisajismo</th>
#       <td id="T_a9207_row10_col0" class="data row10 col0" >USD 150,552.49</td>
#       <td id="T_a9207_row10_col1" class="data row10 col1" >USD -1,912.37</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row11" class="row_heading level0 row11" >Materiales de revestimiento</th>
#       <td id="T_a9207_row11_col0" class="data row11 col0" >USD 629,656.36</td>
#       <td id="T_a9207_row11_col1" class="data row11 col1" >USD -28,869.01</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row12" class="row_heading level0 row12" >Muebles de exterior</th>
#       <td id="T_a9207_row12_col0" class="data row12 col0" >USD 328,932.27</td>
#       <td id="T_a9207_row12_col1" class="data row12 col1" >USD 26,784.59</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row13" class="row_heading level0 row13" >Neumáticos</th>
#       <td id="T_a9207_row13_col0" class="data row13 col0" >USD 1,022,428.97</td>
#       <td id="T_a9207_row13_col1" class="data row13 col1" >USD 67,460.05</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row14" class="row_heading level0 row14" >Pesticidas</th>
#       <td id="T_a9207_row14_col0" class="data row14 col0" >USD 244,956.04</td>
#       <td id="T_a9207_row14_col1" class="data row14 col1" >USD 53,343.89</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row15" class="row_heading level0 row15" >Piezas de repuesto</th>
#       <td id="T_a9207_row15_col0" class="data row15 col0" >USD 486,907.94</td>
#       <td id="T_a9207_row15_col1" class="data row15 col1" >USD 91,148.67</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row16" class="row_heading level0 row16" >Semillas</th>
#       <td id="T_a9207_row16_col0" class="data row16 col0" >USD 39,979.75</td>
#       <td id="T_a9207_row16_col1" class="data row16 col1" >USD 8,865.09</td>
#     </tr>
#   </tbody>
# </table>

# %%
estilo_producto.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_a9207_row0_col0, #T_a9207_row11_col1 {
#   background-color: pink;
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_a9207_row0_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_a9207_row1_col0 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_a9207_row1_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_a9207_row2_col0 {
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_a9207_row2_col1, #T_a9207_row12_col0, #T_a9207_row16_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_a9207_row3_col0 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_a9207_row3_col1 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_a9207_row4_col0 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_a9207_row4_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_a9207_row5_col0 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_a9207_row5_col1 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_a9207_row6_col0 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_a9207_row6_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_a9207_row7_col0 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_a9207_row7_col1, #T_a9207_row14_col1 {
#   background-color: #329b51;
#   color: #f1f1f1;
# }
# #T_a9207_row8_col0 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_a9207_row8_col1 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_a9207_row9_col0 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_a9207_row9_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_a9207_row10_col0 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_a9207_row10_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_a9207_row11_col0 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_a9207_row12_col1 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_a9207_row13_col0, #T_a9207_row15_col1 {
#   background-color: lightgreen;
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a9207_row13_col1 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_a9207_row14_col0 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_a9207_row15_col0 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_a9207_row16_col0 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# </style>
# <table id="T_a9207" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9207_level0_col0" class="col_heading level0 col0" >ventas</th>
#       <th id="T_a9207_level0_col1" class="col_heading level0 col1" >ganancia</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo de producto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9207_level0_row0" class="row_heading level0 row0" >Brotes</th>
#       <td id="T_a9207_row0_col0" class="data row0 col0" >USD 8,811.32</td>
#       <td id="T_a9207_row0_col1" class="data row0 col1" >USD 1,381.42</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row1" class="row_heading level0 row1" >Decoración de jardín</th>
#       <td id="T_a9207_row1_col0" class="data row1 col0" >USD 82,680.08</td>
#       <td id="T_a9207_row1_col1" class="data row1 col1" >USD 9,939.43</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row2" class="row_heading level0 row2" >Equipos de limpieza</th>
#       <td id="T_a9207_row2_col0" class="data row2 col0" >USD 542,304.58</td>
#       <td id="T_a9207_row2_col1" class="data row2 col1" >USD 8,724.39</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row3" class="row_heading level0 row3" >Fertilizantes</th>
#       <td id="T_a9207_row3_col0" class="data row3 col0" >USD 53,144.74</td>
#       <td id="T_a9207_row3_col1" class="data row3 col1" >USD 11,254.88</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row4" class="row_heading level0 row4" >Fontanería</th>
#       <td id="T_a9207_row4_col0" class="data row4 col0" >USD 373,223.88</td>
#       <td id="T_a9207_row4_col1" class="data row4 col1" >USD -5,622.34</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row5" class="row_heading level0 row5" >Herramientas</th>
#       <td id="T_a9207_row5_col0" class="data row5 col0" >USD 995,158.41</td>
#       <td id="T_a9207_row5_col1" class="data row5 col1" >USD 41,020.34</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row6" class="row_heading level0 row6" >Herramientas automotrices</th>
#       <td id="T_a9207_row6_col0" class="data row6 col0" >USD 502,109.29</td>
#       <td id="T_a9207_row6_col1" class="data row6 col1" >USD 63,330.22</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row7" class="row_heading level0 row7" >Herramientas de jardinería</th>
#       <td id="T_a9207_row7_col0" class="data row7 col0" >USD 648,879.72</td>
#       <td id="T_a9207_row7_col1" class="data row7 col1" >USD 53,202.88</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row8" class="row_heading level0 row8" >Iluminación</th>
#       <td id="T_a9207_row8_col0" class="data row8 col0" >USD 275,229.53</td>
#       <td id="T_a9207_row8_col1" class="data row8 col1" >USD 20,264.54</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row9" class="row_heading level0 row9" >Macetas</th>
#       <td id="T_a9207_row9_col0" class="data row9 col0" >USD 696,044.18</td>
#       <td id="T_a9207_row9_col1" class="data row9 col1" >USD 33,941.85</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row10" class="row_heading level0 row10" >Materiales de paisajismo</th>
#       <td id="T_a9207_row10_col0" class="data row10 col0" >USD 150,552.49</td>
#       <td id="T_a9207_row10_col1" class="data row10 col1" >USD -1,912.37</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row11" class="row_heading level0 row11" >Materiales de revestimiento</th>
#       <td id="T_a9207_row11_col0" class="data row11 col0" >USD 629,656.36</td>
#       <td id="T_a9207_row11_col1" class="data row11 col1" >USD -28,869.01</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row12" class="row_heading level0 row12" >Muebles de exterior</th>
#       <td id="T_a9207_row12_col0" class="data row12 col0" >USD 328,932.27</td>
#       <td id="T_a9207_row12_col1" class="data row12 col1" >USD 26,784.59</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row13" class="row_heading level0 row13" >Neumáticos</th>
#       <td id="T_a9207_row13_col0" class="data row13 col0" >USD 1,022,428.97</td>
#       <td id="T_a9207_row13_col1" class="data row13 col1" >USD 67,460.05</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row14" class="row_heading level0 row14" >Pesticidas</th>
#       <td id="T_a9207_row14_col0" class="data row14 col0" >USD 244,956.04</td>
#       <td id="T_a9207_row14_col1" class="data row14 col1" >USD 53,343.89</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row15" class="row_heading level0 row15" >Piezas de repuesto</th>
#       <td id="T_a9207_row15_col0" class="data row15 col0" >USD 486,907.94</td>
#       <td id="T_a9207_row15_col1" class="data row15 col1" >USD 91,148.67</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row16" class="row_heading level0 row16" >Semillas</th>
#       <td id="T_a9207_row16_col0" class="data row16 col0" >USD 39,979.75</td>
#       <td id="T_a9207_row16_col1" class="data row16 col1" >USD 8,865.09</td>
#     </tr>
#   </tbody>
# </table>

# %%
encabezado = {
              'selector':'th',
              'props': 'font-weight: bold; font-family:Arial; text-align:center; text-transform:capitalize'
}

# %%
estilo_producto.set_table_styles([encabezado],overwrite=False)
# Out:
# <style type="text/css">
# #T_a9207 th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: center;
#   text-transform: capitalize;
# }
# #T_a9207_row0_col0, #T_a9207_row11_col1 {
#   background-color: pink;
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_a9207_row0_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_a9207_row1_col0 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_a9207_row1_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_a9207_row2_col0 {
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_a9207_row2_col1, #T_a9207_row12_col0, #T_a9207_row16_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_a9207_row3_col0 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_a9207_row3_col1 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_a9207_row4_col0 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_a9207_row4_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_a9207_row5_col0 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_a9207_row5_col1 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_a9207_row6_col0 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_a9207_row6_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_a9207_row7_col0 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_a9207_row7_col1, #T_a9207_row14_col1 {
#   background-color: #329b51;
#   color: #f1f1f1;
# }
# #T_a9207_row8_col0 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_a9207_row8_col1 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_a9207_row9_col0 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_a9207_row9_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_a9207_row10_col0 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_a9207_row10_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_a9207_row11_col0 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# #T_a9207_row12_col1 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_a9207_row13_col0, #T_a9207_row15_col1 {
#   background-color: lightgreen;
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a9207_row13_col1 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_a9207_row14_col0 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_a9207_row15_col0 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_a9207_row16_col0 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# </style>
# <table id="T_a9207" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9207_level0_col0" class="col_heading level0 col0" >ventas</th>
#       <th id="T_a9207_level0_col1" class="col_heading level0 col1" >ganancia</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo de producto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9207_level0_row0" class="row_heading level0 row0" >Brotes</th>
#       <td id="T_a9207_row0_col0" class="data row0 col0" >USD 8,811.32</td>
#       <td id="T_a9207_row0_col1" class="data row0 col1" >USD 1,381.42</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row1" class="row_heading level0 row1" >Decoración de jardín</th>
#       <td id="T_a9207_row1_col0" class="data row1 col0" >USD 82,680.08</td>
#       <td id="T_a9207_row1_col1" class="data row1 col1" >USD 9,939.43</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row2" class="row_heading level0 row2" >Equipos de limpieza</th>
#       <td id="T_a9207_row2_col0" class="data row2 col0" >USD 542,304.58</td>
#       <td id="T_a9207_row2_col1" class="data row2 col1" >USD 8,724.39</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row3" class="row_heading level0 row3" >Fertilizantes</th>
#       <td id="T_a9207_row3_col0" class="data row3 col0" >USD 53,144.74</td>
#       <td id="T_a9207_row3_col1" class="data row3 col1" >USD 11,254.88</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row4" class="row_heading level0 row4" >Fontanería</th>
#       <td id="T_a9207_row4_col0" class="data row4 col0" >USD 373,223.88</td>
#       <td id="T_a9207_row4_col1" class="data row4 col1" >USD -5,622.34</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row5" class="row_heading level0 row5" >Herramientas</th>
#       <td id="T_a9207_row5_col0" class="data row5 col0" >USD 995,158.41</td>
#       <td id="T_a9207_row5_col1" class="data row5 col1" >USD 41,020.34</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row6" class="row_heading level0 row6" >Herramientas automotrices</th>
#       <td id="T_a9207_row6_col0" class="data row6 col0" >USD 502,109.29</td>
#       <td id="T_a9207_row6_col1" class="data row6 col1" >USD 63,330.22</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row7" class="row_heading level0 row7" >Herramientas de jardinería</th>
#       <td id="T_a9207_row7_col0" class="data row7 col0" >USD 648,879.72</td>
#       <td id="T_a9207_row7_col1" class="data row7 col1" >USD 53,202.88</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row8" class="row_heading level0 row8" >Iluminación</th>
#       <td id="T_a9207_row8_col0" class="data row8 col0" >USD 275,229.53</td>
#       <td id="T_a9207_row8_col1" class="data row8 col1" >USD 20,264.54</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row9" class="row_heading level0 row9" >Macetas</th>
#       <td id="T_a9207_row9_col0" class="data row9 col0" >USD 696,044.18</td>
#       <td id="T_a9207_row9_col1" class="data row9 col1" >USD 33,941.85</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row10" class="row_heading level0 row10" >Materiales de paisajismo</th>
#       <td id="T_a9207_row10_col0" class="data row10 col0" >USD 150,552.49</td>
#       <td id="T_a9207_row10_col1" class="data row10 col1" >USD -1,912.37</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row11" class="row_heading level0 row11" >Materiales de revestimiento</th>
#       <td id="T_a9207_row11_col0" class="data row11 col0" >USD 629,656.36</td>
#       <td id="T_a9207_row11_col1" class="data row11 col1" >USD -28,869.01</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row12" class="row_heading level0 row12" >Muebles de exterior</th>
#       <td id="T_a9207_row12_col0" class="data row12 col0" >USD 328,932.27</td>
#       <td id="T_a9207_row12_col1" class="data row12 col1" >USD 26,784.59</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row13" class="row_heading level0 row13" >Neumáticos</th>
#       <td id="T_a9207_row13_col0" class="data row13 col0" >USD 1,022,428.97</td>
#       <td id="T_a9207_row13_col1" class="data row13 col1" >USD 67,460.05</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row14" class="row_heading level0 row14" >Pesticidas</th>
#       <td id="T_a9207_row14_col0" class="data row14 col0" >USD 244,956.04</td>
#       <td id="T_a9207_row14_col1" class="data row14 col1" >USD 53,343.89</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row15" class="row_heading level0 row15" >Piezas de repuesto</th>
#       <td id="T_a9207_row15_col0" class="data row15 col0" >USD 486,907.94</td>
#       <td id="T_a9207_row15_col1" class="data row15 col1" >USD 91,148.67</td>
#     </tr>
#     <tr>
#       <th id="T_a9207_level0_row16" class="row_heading level0 row16" >Semillas</th>
#       <td id="T_a9207_row16_col0" class="data row16 col0" >USD 39,979.75</td>
#       <td id="T_a9207_row16_col1" class="data row16 col1" >USD 8,865.09</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Misión 3: Equipo de Logística
#
# Necesitamos construir una visualización que nos permita entender la **distribución de pedidos por región de Brasil**.
#
# Así, el equipo de logística va a saber dónde hay más oportunidad de enfocar los esfuerzos de material y mano de obra.

# %%
region = pd.DataFrame(ventas['region'].value_counts())
region.columns = ['N° Pedidos']
region.index.name = 'Región'
region
# Out:
#               N° Pedidos
# Región
# Buenos Aires        2822
# Litoral             1924
# Norte               1555
# Central             1276
# Cuyo                 915
# Patagónica           448

# %%
import numpy as np

# %%
porcentaje = region['N° Pedidos'].to_numpy()
porcentaje = 100*porcentaje/porcentaje.sum()
porcentaje
# Out:
# array([31.56599553, 21.5212528 , 17.39373602, 14.27293065, 10.23489933,
#         5.01118568])

# %%
region['Porcentaje de Pedidos']= porcentaje
region
# Out:
#               N° Pedidos  Porcentaje de Pedidos
# Región
# Buenos Aires        2822              31.565996
# Litoral             1924              21.521253
# Norte               1555              17.393736
# Central             1276              14.272931
# Cuyo                 915              10.234899
# Patagónica           448               5.011186

# %%
estilo_region = region.style
estilo_region
# Out:
# <style type="text/css">
# </style>
# <table id="T_0aa6c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0aa6c_level0_col0" class="col_heading level0 col0" >N° Pedidos</th>
#       <th id="T_0aa6c_level0_col1" class="col_heading level0 col1" >Porcentaje de Pedidos</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Región</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0aa6c_level0_row0" class="row_heading level0 row0" >Buenos Aires</th>
#       <td id="T_0aa6c_row0_col0" class="data row0 col0" >2822</td>
#       <td id="T_0aa6c_row0_col1" class="data row0 col1" >31.565996</td>
#     </tr>
#     <tr>
#       <th id="T_0aa6c_level0_row1" class="row_heading level0 row1" >Litoral</th>
#       <td id="T_0aa6c_row1_col0" class="data row1 col0" >1924</td>
#       <td id="T_0aa6c_row1_col1" class="data row1 col1" >21.521253</td>
#     </tr>
#     <tr>
#       <th id="T_0aa6c_level0_row2" class="row_heading level0 row2" >Norte</th>
#       <td id="T_0aa6c_row2_col0" class="data row2 col0" >1555</td>
#       <td id="T_0aa6c_row2_col1" class="data row2 col1" >17.393736</td>
#     </tr>
#     <tr>
#       <th id="T_0aa6c_level0_row3" class="row_heading level0 row3" >Central</th>
#       <td id="T_0aa6c_row3_col0" class="data row3 col0" >1276</td>
#       <td id="T_0aa6c_row3_col1" class="data row3 col1" >14.272931</td>
#     </tr>
#     <tr>
#       <th id="T_0aa6c_level0_row4" class="row_heading level0 row4" >Cuyo</th>
#       <td id="T_0aa6c_row4_col0" class="data row4 col0" >915</td>
#       <td id="T_0aa6c_row4_col1" class="data row4 col1" >10.234899</td>
#     </tr>
#     <tr>
#       <th id="T_0aa6c_level0_row5" class="row_heading level0 row5" >Patagónica</th>
#       <td id="T_0aa6c_row5_col0" class="data row5 col0" >448</td>
#       <td id="T_0aa6c_row5_col1" class="data row5 col1" >5.011186</td>
#     </tr>
#   </tbody>
# </table>

# %%
encabezado = {
              'selector':'th',#th table head
              'props': 'font-weight: bold; font-family:Arial; text-align:right; background-color:black; text-transform:capitalize'
}
celdas = {
              'selector':'td',#th table data
              'props': 'background-color:gray'
}
estilo_region.set_table_styles([encabezado,celdas])
# Out:
# <style type="text/css">
# #T_0aa6c th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
#   background-color: black;
#   text-transform: capitalize;
# }
# #T_0aa6c td {
#   background-color: gray;
# }
# </style>
# <table id="T_0aa6c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0aa6c_level0_col0" class="col_heading level0 col0" >N° Pedidos</th>
#       <th id="T_0aa6c_level0_col1" class="col_heading level0 col1" >Porcentaje de Pedidos</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Región</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0aa6c_level0_row0" class="row_heading level0 row0" >Buenos Aires</th>
#       <td id="T_0aa6c_row0_col0" class="data row0 col0" >2822</td>
#       <td id="T_0aa6c_row0_col1" class="data row0 col1" >31.565996</td>
#     </tr>
#     <tr>
#       <th id="T_0aa6c_level0_row1" class="row_heading level0 row1" >Litoral</th>
#       <td id="T_0aa6c_row1_col0" class="data row1 col0" >1924</td>
#       <td id="T_0aa6c_row1_col1" class="data row1 col1" >21.521253</td>
#     </tr>
#     <tr>
#       <th id="T_0aa6c_level0_row2" class="row_heading level0 row2" >Norte</th>
#       <td id="T_0aa6c_row2_col0" class="data row2 col0" >1555</td>
#       <td id="T_0aa6c_row2_col1" class="data row2 col1" >17.393736</td>
#     </tr>
#     <tr>
#       <th id="T_0aa6c_level0_row3" class="row_heading level0 row3" >Central</th>
#       <td id="T_0aa6c_row3_col0" class="data row3 col0" >1276</td>
#       <td id="T_0aa6c_row3_col1" class="data row3 col1" >14.272931</td>
#     </tr>
#     <tr>
#       <th id="T_0aa6c_level0_row4" class="row_heading level0 row4" >Cuyo</th>
#       <td id="T_0aa6c_row4_col0" class="data row4 col0" >915</td>
#       <td id="T_0aa6c_row4_col1" class="data row4 col1" >10.234899</td>
#     </tr>
#     <tr>
#       <th id="T_0aa6c_level0_row5" class="row_heading level0 row5" >Patagónica</th>
#       <td id="T_0aa6c_row5_col0" class="data row5 col0" >448</td>
#       <td id="T_0aa6c_row5_col1" class="data row5 col1" >5.011186</td>
#     </tr>
#   </tbody>
# </table>

# %%
estilo_region.format({'Porcentaje de Pedidos':'{:,.2f}%'})\
                    .bar(subset='Porcentaje de Pedidos',vmin=0,vmax=100, color='#d65f5f')
# Out:
# <style type="text/css">
# #T_0aa6c th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
#   background-color: black;
#   text-transform: capitalize;
# }
# #T_0aa6c td {
#   background-color: gray;
# }
# #T_0aa6c_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 31.6%, transparent 31.6%);
# }
# #T_0aa6c_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.5%, transparent 21.5%);
# }
# #T_0aa6c_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.4%, transparent 17.4%);
# }
# #T_0aa6c_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.3%, transparent 14.3%);
# }
# #T_0aa6c_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.2%, transparent 10.2%);
# }
# #T_0aa6c_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.0%, transparent 5.0%);
# }
# </style>
# <table id="T_0aa6c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0aa6c_level0_col0" class="col_heading level0 col0" >N° Pedidos</th>
#       <th id="T_0aa6c_level0_col1" class="col_heading level0 col1" >Porcentaje de Pedidos</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Región</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0aa6c_level0_row0" class="row_heading level0 row0" >Buenos Aires</th>
#       <td id="T_0aa6c_row0_col0" class="data row0 col0" >2822</td>
#       <td id="T_0aa6c_row0_col1" class="data row0 col1" >31.57%</td>
#     </tr>
#     <tr>
#       <th id="T_0aa6c_level0_row1" class="row_heading level0 row1" >Litoral</th>
#       <td id="T_0aa6c_row1_col0" class="data row1 col0" >1924</td>
#       <td id="T_0aa6c_row1_col1" class="data row1 col1" >21.52%</td>
#     </tr>
#     <tr>
#       <th id="T_0aa6c_level0_row2" class="row_heading level0 row2" >Norte</th>
#       <td id="T_0aa6c_row2_col0" class="data row2 col0" >1555</td>
#       <td id="T_0aa6c_row2_col1" class="data row2 col1" >17.39%</td>
#     </tr>
#     <tr>
#       <th id="T_0aa6c_level0_row3" class="row_heading level0 row3" >Central</th>
#       <td id="T_0aa6c_row3_col0" class="data row3 col0" >1276</td>
#       <td id="T_0aa6c_row3_col1" class="data row3 col1" >14.27%</td>
#     </tr>
#     <tr>
#       <th id="T_0aa6c_level0_row4" class="row_heading level0 row4" >Cuyo</th>
#       <td id="T_0aa6c_row4_col0" class="data row4 col0" >915</td>
#       <td id="T_0aa6c_row4_col1" class="data row4 col1" >10.23%</td>
#     </tr>
#     <tr>
#       <th id="T_0aa6c_level0_row5" class="row_heading level0 row5" >Patagónica</th>
#       <td id="T_0aa6c_row5_col0" class="data row5 col0" >448</td>
#       <td id="T_0aa6c_row5_col1" class="data row5 col1" >5.01%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Misión 4: Equipo de Logística
#
# Nuevamente el equipo de logística desea replantear su estructura y organización de provisionamiento de productos e, para ello, se pensó en una visualización que permita identificar el estándar de la **cantidad de productos solicitados por mes por departamento**.

# %%
meses = ventas.copy()
meses = meses.sort_values('fecha_pedido')
meses.head()
# Out:
#      fecha_pedido        modo_envio    nombre_cliente segmento_cliente  \
# 7171   2016-01-04  Entrega estándar     Ramiro Guzmán              B2C
# 651    2016-01-05  Entrega estándar   Jerónimo Cortés              B2B
# 650    2016-01-05  Entrega estándar   Jerónimo Cortés              B2B
# 649    2016-01-05  Entrega estándar   Jerónimo Cortés              B2B
# 1576   2016-01-06  Entrega estándar  Florencia Chávez              B2C
#
#                                ciudad                        provincia  \
# 7171                          Rosario                         Santa Fe
# 651                         Pergamino                     Buenos Aires
# 650                         Pergamino                     Buenos Aires
# 649                         Pergamino                     Buenos Aires
# 1576  Ciudad Autónoma de Buenos Aires  Ciudad Autónoma de Buenos Aires
#
#             region             departamento               tipo_producto  \
# 7171       Litoral  Jardinería y paisajismo                  Pesticidas
# 651   Buenos Aires  Jardinería y paisajismo  Herramientas de jardinería
# 650   Buenos Aires  Jardinería y paisajismo                     Macetas
# 649   Buenos Aires  Jardinería y paisajismo                    Semillas
# 1576  Buenos Aires  Jardinería y paisajismo        Decoración de jardín
#
#       cantidad  ventas  ganancia
# 7171         2   55.92      9.44
# 651          2   12.04     -9.32
# 650          3  927.30   -110.13
# 649          3   40.08      7.26
# 1576         3   66.42      8.31

# %%
meses['mes'] = meses['fecha_pedido'].dt.strftime('%Y - %b')
meses = meses.reset_index(drop=True)
meses.head()
# Out:
#   fecha_pedido        modo_envio    nombre_cliente segmento_cliente  \
# 0   2016-01-04  Entrega estándar     Ramiro Guzmán              B2C
# 1   2016-01-05  Entrega estándar   Jerónimo Cortés              B2B
# 2   2016-01-05  Entrega estándar   Jerónimo Cortés              B2B
# 3   2016-01-05  Entrega estándar   Jerónimo Cortés              B2B
# 4   2016-01-06  Entrega estándar  Florencia Chávez              B2C
#
#                             ciudad                        provincia  \
# 0                          Rosario                         Santa Fe
# 1                        Pergamino                     Buenos Aires
# 2                        Pergamino                     Buenos Aires
# 3                        Pergamino                     Buenos Aires
# 4  Ciudad Autónoma de Buenos Aires  Ciudad Autónoma de Buenos Aires
#
#          region             departamento               tipo_producto  \
# 0       Litoral  Jardinería y paisajismo                  Pesticidas
# 1  Buenos Aires  Jardinería y paisajismo  Herramientas de jardinería
# 2  Buenos Aires  Jardinería y paisajismo                     Macetas
# 3  Buenos Aires  Jardinería y paisajismo                    Semillas
# 4  Buenos Aires  Jardinería y paisajismo        Decoración de jardín
#
#    cantidad  ventas  ganancia         mes
# 0         2   55.92      9.44  2016 - Jan
# 1         2   12.04     -9.32  2016 - Jan
# 2         3  927.30   -110.13  2016 - Jan
# 3         3   40.08      7.26  2016 - Jan
# 4         3   66.42      8.31  2016 - Jan

# %%
pd.set_option('display.max_columns', None)

# %%
ventas_mensuales = meses.pivot_table(index=meses.departamento, columns='mes', values='cantidad', aggfunc='sum', sort=False)
ventas_mensuales
# Out:
# mes                         2016 - Jan  2016 - Feb  2016 - Mar  2016 - Apr  \
# departamento
# Jardinería y paisajismo            161          87         277         323
# Automotriz                          45          20          46         107
# Materiales de construcción          60          23         102          69
#
# mes                         2016 - May  2016 - Jun  2016 - Jul  2016 - Aug  \
# departamento
# Jardinería y paisajismo            270         273         348         339
# Automotriz                          81          83          91          95
# Materiales de construcción          91         114         104         101
#
# mes                         2016 - Sep  2016 - Oct  2016 - Nov  2016 - Dec  \
# departamento
# Jardinería y paisajismo            549         276         716         525
# Automotriz                         154          85         236         154
# Materiales de construcción         182          94         213         269
#
# mes                         2017 - Jan  2017 - Feb  2017 - Mar  2017 - Apr  \
# departamento
# Jardinería y paisajismo             97         131         278         271
# Automotriz                          55          44          74         111
# Materiales de construcción          93          38         100          85
#
# mes                         2017 - May  2017 - Jun  2017 - Jul  2017 - Aug  \
# departamento
# Jardinería y paisajismo            269         321         268         322
# Automotriz                          94          59          88         117
# Materiales de construcción          76         120         128         106
#
# mes                         2017 - Sep  2017 - Oct  2017 - Nov  2017 - Dec  \
# departamento
# Jardinería y paisajismo            663         260         746         628
# Automotriz                         180         100         179         235
# Materiales de construcción         194         129         259         258
#
# mes                         2018 - Jan  2018 - Feb  2018 - Mar  2018 - Apr  \
# departamento
# Jardinería y paisajismo            190         177         260         338
# Automotriz                          59          49         112          72
# Materiales de construcción          91          67         127         128
#
# mes                         2018 - May  2018 - Jun  2018 - Jul  2018 - Aug  \
# departamento
# Jardinería y paisajismo            463         473         413         380
# Automotriz                         124         118         117         123
# Materiales de construcción         171         117         132         113
#
# mes                         2018 - Sep  2018 - Oct  2018 - Nov  2018 - Dec  \
# departamento
# Jardinería y paisajismo            757         402         727         770
# Automotriz                         181         103         253         189
# Materiales de construcción         227         171         308         294
#
# mes                         2019 - Jan  2019 - Feb  2019 - Mar  2019 - Apr  \
# departamento
# Jardinería y paisajismo            361         205         458         415
# Automotriz                         109          63         167          87
# Materiales de construcción          83          67         107         131
#
# mes                         2019 - May  2019 - Jun  2019 - Jul  2019 - Aug  \
# departamento
# Jardinería y paisajismo            542         490         423         561
# Automotriz                         150         170         168         136
# Materiales de construcción         172         151         162         132
#
# mes                         2019 - Sep  2019 - Oct  2019 - Nov  2019 - Dec
# departamento
# Jardinería y paisajismo            929         617         946         989
# Automotriz                         280         205         331         252
# Materiales de construcción         282         213         312         395

# %%
estilo_mensual = ventas_mensuales.style
estilo_mensual
# Out:
# <style type="text/css">
# </style>
# <table id="T_db15e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mes</th>
#       <th id="T_db15e_level0_col0" class="col_heading level0 col0" >2016 - Jan</th>
#       <th id="T_db15e_level0_col1" class="col_heading level0 col1" >2016 - Feb</th>
#       <th id="T_db15e_level0_col2" class="col_heading level0 col2" >2016 - Mar</th>
#       <th id="T_db15e_level0_col3" class="col_heading level0 col3" >2016 - Apr</th>
#       <th id="T_db15e_level0_col4" class="col_heading level0 col4" >2016 - May</th>
#       <th id="T_db15e_level0_col5" class="col_heading level0 col5" >2016 - Jun</th>
#       <th id="T_db15e_level0_col6" class="col_heading level0 col6" >2016 - Jul</th>
#       <th id="T_db15e_level0_col7" class="col_heading level0 col7" >2016 - Aug</th>
#       <th id="T_db15e_level0_col8" class="col_heading level0 col8" >2016 - Sep</th>
#       <th id="T_db15e_level0_col9" class="col_heading level0 col9" >2016 - Oct</th>
#       <th id="T_db15e_level0_col10" class="col_heading level0 col10" >2016 - Nov</th>
#       <th id="T_db15e_level0_col11" class="col_heading level0 col11" >2016 - Dec</th>
#       <th id="T_db15e_level0_col12" class="col_heading level0 col12" >2017 - Jan</th>
#       <th id="T_db15e_level0_col13" class="col_heading level0 col13" >2017 - Feb</th>
#       <th id="T_db15e_level0_col14" class="col_heading level0 col14" >2017 - Mar</th>
#       <th id="T_db15e_level0_col15" class="col_heading level0 col15" >2017 - Apr</th>
#       <th id="T_db15e_level0_col16" class="col_heading level0 col16" >2017 - May</th>
#       <th id="T_db15e_level0_col17" class="col_heading level0 col17" >2017 - Jun</th>
#       <th id="T_db15e_level0_col18" class="col_heading level0 col18" >2017 - Jul</th>
#       <th id="T_db15e_level0_col19" class="col_heading level0 col19" >2017 - Aug</th>
#       <th id="T_db15e_level0_col20" class="col_heading level0 col20" >2017 - Sep</th>
#       <th id="T_db15e_level0_col21" class="col_heading level0 col21" >2017 - Oct</th>
#       <th id="T_db15e_level0_col22" class="col_heading level0 col22" >2017 - Nov</th>
#       <th id="T_db15e_level0_col23" class="col_heading level0 col23" >2017 - Dec</th>
#       <th id="T_db15e_level0_col24" class="col_heading level0 col24" >2018 - Jan</th>
#       <th id="T_db15e_level0_col25" class="col_heading level0 col25" >2018 - Feb</th>
#       <th id="T_db15e_level0_col26" class="col_heading level0 col26" >2018 - Mar</th>
#       <th id="T_db15e_level0_col27" class="col_heading level0 col27" >2018 - Apr</th>
#       <th id="T_db15e_level0_col28" class="col_heading level0 col28" >2018 - May</th>
#       <th id="T_db15e_level0_col29" class="col_heading level0 col29" >2018 - Jun</th>
#       <th id="T_db15e_level0_col30" class="col_heading level0 col30" >2018 - Jul</th>
#       <th id="T_db15e_level0_col31" class="col_heading level0 col31" >2018 - Aug</th>
#       <th id="T_db15e_level0_col32" class="col_heading level0 col32" >2018 - Sep</th>
#       <th id="T_db15e_level0_col33" class="col_heading level0 col33" >2018 - Oct</th>
#       <th id="T_db15e_level0_col34" class="col_heading level0 col34" >2018 - Nov</th>
#       <th id="T_db15e_level0_col35" class="col_heading level0 col35" >2018 - Dec</th>
#       <th id="T_db15e_level0_col36" class="col_heading level0 col36" >2019 - Jan</th>
#       <th id="T_db15e_level0_col37" class="col_heading level0 col37" >2019 - Feb</th>
#       <th id="T_db15e_level0_col38" class="col_heading level0 col38" >2019 - Mar</th>
#       <th id="T_db15e_level0_col39" class="col_heading level0 col39" >2019 - Apr</th>
#       <th id="T_db15e_level0_col40" class="col_heading level0 col40" >2019 - May</th>
#       <th id="T_db15e_level0_col41" class="col_heading level0 col41" >2019 - Jun</th>
#       <th id="T_db15e_level0_col42" class="col_heading level0 col42" >2019 - Jul</th>
#       <th id="T_db15e_level0_col43" class="col_heading level0 col43" >2019 - Aug</th>
#       <th id="T_db15e_level0_col44" class="col_heading level0 col44" >2019 - Sep</th>
#       <th id="T_db15e_level0_col45" class="col_heading level0 col45" >2019 - Oct</th>
#       <th id="T_db15e_level0_col46" class="col_heading level0 col46" >2019 - Nov</th>
#       <th id="T_db15e_level0_col47" class="col_heading level0 col47" >2019 - Dec</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >departamento</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#       <th class="blank col31" >&nbsp;</th>
#       <th class="blank col32" >&nbsp;</th>
#       <th class="blank col33" >&nbsp;</th>
#       <th class="blank col34" >&nbsp;</th>
#       <th class="blank col35" >&nbsp;</th>
#       <th class="blank col36" >&nbsp;</th>
#       <th class="blank col37" >&nbsp;</th>
#       <th class="blank col38" >&nbsp;</th>
#       <th class="blank col39" >&nbsp;</th>
#       <th class="blank col40" >&nbsp;</th>
#       <th class="blank col41" >&nbsp;</th>
#       <th class="blank col42" >&nbsp;</th>
#       <th class="blank col43" >&nbsp;</th>
#       <th class="blank col44" >&nbsp;</th>
#       <th class="blank col45" >&nbsp;</th>
#       <th class="blank col46" >&nbsp;</th>
#       <th class="blank col47" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db15e_level0_row0" class="row_heading level0 row0" >Jardinería y paisajismo</th>
#       <td id="T_db15e_row0_col0" class="data row0 col0" >161</td>
#       <td id="T_db15e_row0_col1" class="data row0 col1" >87</td>
#       <td id="T_db15e_row0_col2" class="data row0 col2" >277</td>
#       <td id="T_db15e_row0_col3" class="data row0 col3" >323</td>
#       <td id="T_db15e_row0_col4" class="data row0 col4" >270</td>
#       <td id="T_db15e_row0_col5" class="data row0 col5" >273</td>
#       <td id="T_db15e_row0_col6" class="data row0 col6" >348</td>
#       <td id="T_db15e_row0_col7" class="data row0 col7" >339</td>
#       <td id="T_db15e_row0_col8" class="data row0 col8" >549</td>
#       <td id="T_db15e_row0_col9" class="data row0 col9" >276</td>
#       <td id="T_db15e_row0_col10" class="data row0 col10" >716</td>
#       <td id="T_db15e_row0_col11" class="data row0 col11" >525</td>
#       <td id="T_db15e_row0_col12" class="data row0 col12" >97</td>
#       <td id="T_db15e_row0_col13" class="data row0 col13" >131</td>
#       <td id="T_db15e_row0_col14" class="data row0 col14" >278</td>
#       <td id="T_db15e_row0_col15" class="data row0 col15" >271</td>
#       <td id="T_db15e_row0_col16" class="data row0 col16" >269</td>
#       <td id="T_db15e_row0_col17" class="data row0 col17" >321</td>
#       <td id="T_db15e_row0_col18" class="data row0 col18" >268</td>
#       <td id="T_db15e_row0_col19" class="data row0 col19" >322</td>
#       <td id="T_db15e_row0_col20" class="data row0 col20" >663</td>
#       <td id="T_db15e_row0_col21" class="data row0 col21" >260</td>
#       <td id="T_

# %%
estilo_mensual.set_sticky(axis='index') ##fijar la primera columna
# Out:
# <style type="text/css">
# #T_db15e thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_db15e tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# </style>
# <table id="T_db15e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mes</th>
#       <th id="T_db15e_level0_col0" class="col_heading level0 col0" >2016 - Jan</th>
#       <th id="T_db15e_level0_col1" class="col_heading level0 col1" >2016 - Feb</th>
#       <th id="T_db15e_level0_col2" class="col_heading level0 col2" >2016 - Mar</th>
#       <th id="T_db15e_level0_col3" class="col_heading level0 col3" >2016 - Apr</th>
#       <th id="T_db15e_level0_col4" class="col_heading level0 col4" >2016 - May</th>
#       <th id="T_db15e_level0_col5" class="col_heading level0 col5" >2016 - Jun</th>
#       <th id="T_db15e_level0_col6" class="col_heading level0 col6" >2016 - Jul</th>
#       <th id="T_db15e_level0_col7" class="col_heading level0 col7" >2016 - Aug</th>
#       <th id="T_db15e_level0_col8" class="col_heading level0 col8" >2016 - Sep</th>
#       <th id="T_db15e_level0_col9" class="col_heading level0 col9" >2016 - Oct</th>
#       <th id="T_db15e_level0_col10" class="col_heading level0 col10" >2016 - Nov</th>
#       <th id="T_db15e_level0_col11" class="col_heading level0 col11" >2016 - Dec</th>
#       <th id="T_db15e_level0_col12" class="col_heading level0 col12" >2017 - Jan</th>
#       <th id="T_db15e_level0_col13" class="col_heading level0 col13" >2017 - Feb</th>
#       <th id="T_db15e_level0_col14" class="col_heading level0 col14" >2017 - Mar</th>
#       <th id="T_db15e_level0_col15" class="col_heading level0 col15" >2017 - Apr</th>
#       <th id="T_db15e_level0_col16" class="col_heading level0 col16" >2017 - May</th>
#       <th id="T_db15e_level0_col17" class="col_heading level0 col17" >2017 - Jun</th>
#       <th id="T_db15e_level0_col18" class="col_heading level0 col18" >2017 - Jul</th>
#       <th id="T_db15e_level0_col19" class="col_heading level0 col19" >2017 - Aug</th>
#       <th id="T_db15e_level0_col20" class="col_heading level0 col20" >2017 - Sep</th>
#       <th id="T_db15e_level0_col21" class="col_heading level0 col21" >2017 - Oct</th>
#       <th id="T_db15e_level0_col22" class="col_heading level0 col22" >2017 - Nov</th>
#       <th id="T_db15e_level0_col23" class="col_heading level0 col23" >2017 - Dec</th>
#       <th id="T_db15e_level0_col24" class="col_heading level0 col24" >2018 - Jan</th>
#       <th id="T_db15e_level0_col25" class="col_heading level0 col25" >2018 - Feb</th>
#       <th id="T_db15e_level0_col26" class="col_heading level0 col26" >2018 - Mar</th>
#       <th id="T_db15e_level0_col27" class="col_heading level0 col27" >2018 - Apr</th>
#       <th id="T_db15e_level0_col28" class="col_heading level0 col28" >2018 - May</th>
#       <th id="T_db15e_level0_col29" class="col_heading level0 col29" >2018 - Jun</th>
#       <th id="T_db15e_level0_col30" class="col_heading level0 col30" >2018 - Jul</th>
#       <th id="T_db15e_level0_col31" class="col_heading level0 col31" >2018 - Aug</th>
#       <th id="T_db15e_level0_col32" class="col_heading level0 col32" >2018 - Sep</th>
#       <th id="T_db15e_level0_col33" class="col_heading level0 col33" >2018 - Oct</th>
#       <th id="T_db15e_level0_col34" class="col_heading level0 col34" >2018 - Nov</th>
#       <th id="T_db15e_level0_col35" class="col_heading level0 col35" >2018 - Dec</th>
#       <th id="T_db15e_level0_col36" class="col_heading level0 col36" >2019 - Jan</th>
#       <th id="T_db15e_level0_col37" class="col_heading level0 col37" >2019 - Feb</th>
#       <th id="T_db15e_level0_col38" class="col_heading level0 col38" >2019 - Mar</th>
#       <th id="T_db15e_level0_col39" class="col_heading level0 col39" >2019 - Apr</th>
#       <th id="T_db15e_level0_col40" class="col_heading level0 col40" >2019 - May</th>
#       <th id="T_db15e_level0_col41" class="col_heading level0 col41" >2019 - Jun</th>
#       <th id="T_db15e_level0_col42" class="col_heading level0 col42" >2019 - Jul</th>
#       <th id="T_db15e_level0_col43" class="col_heading level0 col43" >2019 - Aug</th>
#       <th id="T_db15e_level0_col44" class="col_heading level0 col44" >2019 - Sep</th>
#       <th id="T_db15e_level0_col45" class="col_heading level0 col45" >2019 - Oct</th>
#       <th id="T_db15e_level0_col46" class="col_heading level0 col46" >2019 - Nov</th>
#       <th id="T_db15e_level0_col47" class="col_heading level0 col47" >2019 - Dec</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >departamento</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#       <th class="blank col31" >&nbsp;</th>
#       <th class="blank col32" >&nbsp;</th>
#       <th class="blank col33" >&nbsp;</th>
#       <th class="blank col34" >&nbsp;</th>
#       <th class="blank col35" >&nbsp;</th>
#       <th class="blank col36" >&nbsp;</th>
#       <th class="blank col37" >&nbsp;</th>
#       <th class="blank col38" >&nbsp;</th>
#       <th class="blank col39" >&nbsp;</th>
#       <th class="blank col40" >&nbsp;</th>
#       <th class="blank col41" >&nbsp;</th>
#       <th class="blank col42" >&nbsp;</th>
#       <th class="blank col43" >&nbsp;</th>
#       <th class="blank col44" >&nbsp;</th>
#       <th class="blank col45" >&nbsp;</th>
#       <th class="blank col46" >&nbsp;</th>
#       <th class="blank col47" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db15e_level0_row0" class="row_heading level0 row0" >Jardinería y paisajismo</th>
#       <td id="T_db15e_row0_col0" class="data row0 col0" >161</td>
#       <td id="T_db15e_row0_col1" class="data row0 col1" >87</td>
#       <td id="T_db15e_row0_col2" class="data row0 col2" >277</td>
#       <td id="T_db15e_row0_col3" class="data row0 col3" >323</td>
#       <td id="T_db15e_row0_col4" class="data row0 col4" >270</td>
#       <td id="T_db15e_row0_col5" class="data row0 col5" >273</td>
#       <td id="T_db15e_row0_col6" class="data row0 col6" >348</td>
#       <td id="T_db15e_row0_col7" class="data row0 col7" >339</td>
#       <td id="T_db15e_row0_col8" class="data row0 col8" >549</td>
#       <td id="T_db15e_row0_col9" class="data row0 col9" >276</td>
#       <td id="T_db15e_row0_col10" class="data row0 col10" >716</td>
#       <td id="T_db15e_row0_col11" class="data row0 col11" >525</td>
#       <td id="T_db15e_row0_col12" class="data row0 col12" >97</td>
#       <td id="T_db15e_row0_col13" class="data row0 col13" >131</td>
#       <td id="T_db15e_row0_col14" class="data row0 col14" >278</td>
#       <td id="T_db15e_row0_col15" class="data row0 col15" >271</td>
#       <td id="T_db15e_row0_col16" class="data row0 col16" >269</td>
#       <td id="T_db15e_row0_col17" class="data row0 col17" >321</td>
#       <td id="T_db15e_row0_col18" class="data row

# %%
columnas = {
            'selector':'.col_heading',
            'props':'font-weight:normal;font-family:Arial'
}
tabla = {
            'selector':'td,th',
            'props':'text-align:left'
}
indices = {
            'selector':'.index_name',
            'props':'font-weight:bold;font-family:Arial;text-align:right'
}
estilo_mensual.set_table_styles([columnas,tabla,indices],overwrite=False)
# Out:
# <style type="text/css">
# #T_db15e thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_db15e tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# #T_db15e .col_heading {
#   font-weight: normal;
#   font-family: Arial;
# }
# #T_db15e td {
#   text-align: left;
# }
# #T_db15e th {
#   text-align: left;
# }
# #T_db15e .index_name {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
# }
# #T_db15e .col_heading {
#   font-weight: normal;
#   font-family: Arial;
# }
# #T_db15e td {
#   text-align: left;
# }
# #T_db15e th {
#   text-align: left;
# }
# #T_db15e .index_name {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: right;
# }
# </style>
# <table id="T_db15e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >mes</th>
#       <th id="T_db15e_level0_col0" class="col_heading level0 col0" >2016 - Jan</th>
#       <th id="T_db15e_level0_col1" class="col_heading level0 col1" >2016 - Feb</th>
#       <th id="T_db15e_level0_col2" class="col_heading level0 col2" >2016 - Mar</th>
#       <th id="T_db15e_level0_col3" class="col_heading level0 col3" >2016 - Apr</th>
#       <th id="T_db15e_level0_col4" class="col_heading level0 col4" >2016 - May</th>
#       <th id="T_db15e_level0_col5" class="col_heading level0 col5" >2016 - Jun</th>
#       <th id="T_db15e_level0_col6" class="col_heading level0 col6" >2016 - Jul</th>
#       <th id="T_db15e_level0_col7" class="col_heading level0 col7" >2016 - Aug</th>
#       <th id="T_db15e_level0_col8" class="col_heading level0 col8" >2016 - Sep</th>
#       <th id="T_db15e_level0_col9" class="col_heading level0 col9" >2016 - Oct</th>
#       <th id="T_db15e_level0_col10" class="col_heading level0 col10" >2016 - Nov</th>
#       <th id="T_db15e_level0_col11" class="col_heading level0 col11" >2016 - Dec</th>
#       <th id="T_db15e_level0_col12" class="col_heading level0 col12" >2017 - Jan</th>
#       <th id="T_db15e_level0_col13" class="col_heading level0 col13" >2017 - Feb</th>
#       <th id="T_db15e_level0_col14" class="col_heading level0 col14" >2017 - Mar</th>
#       <th id="T_db15e_level0_col15" class="col_heading level0 col15" >2017 - Apr</th>
#       <th id="T_db15e_level0_col16" class="col_heading level0 col16" >2017 - May</th>
#       <th id="T_db15e_level0_col17" class="col_heading level0 col17" >2017 - Jun</th>
#       <th id="T_db15e_level0_col18" class="col_heading level0 col18" >2017 - Jul</th>
#       <th id="T_db15e_level0_col19" class="col_heading level0 col19" >2017 - Aug</th>
#       <th id="T_db15e_level0_col20" class="col_heading level0 col20" >2017 - Sep</th>
#       <th id="T_db15e_level0_col21" class="col_heading level0 col21" >2017 - Oct</th>
#       <th id="T_db15e_level0_col22" class="col_heading level0 col22" >2017 - Nov</th>
#       <th id="T_db15e_level0_col23" class="col_heading level0 col23" >2017 - Dec</th>
#       <th id="T_db15e_level0_col24" class="col_heading level0 col24" >2018 - Jan</th>
#       <th id="T_db15e_level0_col25" class="col_heading level0 col25" >2018 - Feb</th>
#       <th id="T_db15e_level0_col26" class="col_heading level0 col26" >2018 - Mar</th>
#       <th id="T_db15e_level0_col27" class="col_heading level0 col27" >2018 - Apr</th>
#       <th id="T_db15e_level0_col28" class="col_heading level0 col28" >2018 - May</th>
#       <th id="T_db15e_level0_col29" class="col_heading level0 col29" >2018 - Jun</th>
#       <th id="T_db15e_level0_col30" class="col_heading level0 col30" >2018 - Jul</th>
#       <th id="T_db15e_level0_col31" class="col_heading level0 col31" >2018 - Aug</th>
#       <th id="T_db15e_level0_col32" class="col_heading level0 col32" >2018 - Sep</th>
#       <th id="T_db15e_level0_col33" class="col_heading level0 col33" >2018 - Oct</th>
#       <th id="T_db15e_level0_col34" class="col_heading level0 col34" >2018 - Nov</th>
#       <th id="T_db15e_level0_col35" class="col_heading level0 col35" >2018 - Dec</th>
#       <th id="T_db15e_level0_col36" class="col_heading level0 col36" >2019 - Jan</th>
#       <th id="T_db15e_level0_col37" class="col_heading level0 col37" >2019 - Feb</th>
#       <th id="T_db15e_level0_col38" class="col_heading level0 col38" >2019 - Mar</th>
#       <th id="T_db15e_level0_col39" class="col_heading level0 col39" >2019 - Apr</th>
#       <th id="T_db15e_level0_col40" class="col_heading level0 col40" >2019 - May</th>
#       <th id="T_db15e_level0_col41" class="col_heading level0 col41" >2019 - Jun</th>
#       <th id="T_db15e_level0_col42" class="col_heading level0 col42" >2019 - Jul</th>
#       <th id="T_db15e_level0_col43" class="col_heading level0 col43" >2019 - Aug</th>
#       <th id="T_db15e_level0_col44" class="col_heading level0 col44" >2019 - Sep</th>
#       <th id="T_db15e_level0_col45" class="col_heading level0 col45" >2019 - Oct</th>
#       <th id="T_db15e_level0_col46" class="col_heading level0 col46" >2019 - Nov</th>
#       <th id="T_db15e_level0_col47" class="col_heading level0 col47" >2019 - Dec</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >departamento</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#       <th class="blank col26" >&nbsp;</th>
#       <th class="blank col27" >&nbsp;</th>
#       <th class="blank col28" >&nbsp;</th>
#       <th class="blank col29" >&nbsp;</th>
#       <th class="blank col30" >&nbsp;</th>
#       <th class="blank col31" >&nbsp;</th>
#       <th class="blank col32" >&nbsp;</th>
#       <th class="blank col33" >&nbsp;</th>
#       <th class="blank col34" >&nbsp;</th>
#       <th class="blank col35" >&nbsp;</th>
#       <th class="blank col36" >&nbsp;</th>
#       <th class="blank col37" >&nbsp;</th>
#       <th class="blank col38" >&nbsp;</th>
#       <th class="blank col39" >&nbsp;</th>
#       <th class="blank col40" >&nbsp;</th>
#       <th class="blank col41" >&nbsp;</th>
#       <th class="blank col42" >&nbsp;</th>
#       <th class="blank col43" >&nbsp;</th>
#       <th class="blank col44" >&nbsp;</th>
#       <th class="blank col45" >&nbsp;</th>
#       <th class="blank col46" >&nbsp;</th>
#       <th class="blank col47" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db15e_level0_row0" class="row_heading level0 row0" >Jardinería y paisajismo</th>
#       <td id="T_db15e_row0_col0" class="data row0 col0" >161</td>
#       <td id="T_db15e_row0_col1" class="data row0 col1" >87</td>
#       <td id="T_db15e_row0_col2" class="data row0 col2" >277</td>
#       <td id="T_db15e_row0_col3" class="data row0 col3" >323</td>
#       <td id="T_db15e_row0_col4" class="data row0 col4" >270</td>
#       <td id="T_db15e_row0_col5" class="data row0 col5" >273</td>
#       <td id="T_db15e_row0_col6" class="data row0 col6" >348</td>
#       <td id="T_db15e_row0_col7" class="data row0 col7" >339</td>
#       <td id="T_db15e_row0_col8" class="data row0 col8" >549</td>
#       <td id="T_db15e_row0_col9" class="data row0 col9" >276</td>
#       <td id="T_db15e_row0_col10" class="data row0 col10" >716</td>
#       <td id="T_db15e_row0_col11" class="data row0 col11" >5

# %% [markdown]
# # Misión 5: Informe de Desempeño
#
# El informe de desempeño es un documento muy importante para la empresa. En este, todos los que trabajan en la tienda pueden entender cómo está la empresa. Debido a ello, las tablas bien construídas son esenciales para mostrar los datos de la mejor forma.
#
# Por lo tanto, necesitamos construir una visualización que permita entender la **relación entre tipos de clientes y modo de envío de productos de acuerdo con las ventas**. De esta forma, será posible destacar en el informe cuál es el modo de envío y cuáles son los que más generaron lucro en las ventas.

# %%
df_cliente = ventas.pivot_table(index='segmento_cliente',columns='modo_envio',values='ventas',aggfunc='sum')
df_cliente
# Out:
# modo_envio        Económica  Entrega en 24 horas  Entrega estándar  \
# segmento_cliente
# B2B               718461.22            217465.60        1884738.56
# B2C               729174.73            182531.47        2248283.69
#
# modo_envio        Envío rápido
# segmento_cliente
# B2B                  602049.40
# B2C                  498294.88

# %%
df_cliente['Total']= df_cliente.sum(axis=1)
df_cliente.loc['Total']= df_cliente.sum()
df_cliente
# Out:
# modo_envio         Económica  Entrega en 24 horas  Entrega estándar  \
# segmento_cliente
# B2B                718461.22            217465.60        1884738.56
# B2C                729174.73            182531.47        2248283.69
# Total             1447635.95            399997.07        4133022.25
#
# modo_envio        Envío rápido       Total
# segmento_cliente
# B2B                  602049.40  3422714.78
# B2C                  498294.88  3658284.77
# Total               1100344.28  7080999.55

# %%
compra_cliente = df_cliente.style.format('{:,.2f}')
compra_cliente
# Out:
# <style type="text/css">
# </style>
# <table id="T_dc54f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >modo_envio</th>
#       <th id="T_dc54f_level0_col0" class="col_heading level0 col0" >Económica</th>
#       <th id="T_dc54f_level0_col1" class="col_heading level0 col1" >Entrega en 24 horas</th>
#       <th id="T_dc54f_level0_col2" class="col_heading level0 col2" >Entrega estándar</th>
#       <th id="T_dc54f_level0_col3" class="col_heading level0 col3" >Envío rápido</th>
#       <th id="T_dc54f_level0_col4" class="col_heading level0 col4" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >segmento_cliente</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc54f_level0_row0" class="row_heading level0 row0" >B2B</th>
#       <td id="T_dc54f_row0_col0" class="data row0 col0" >718,461.22</td>
#       <td id="T_dc54f_row0_col1" class="data row0 col1" >217,465.60</td>
#       <td id="T_dc54f_row0_col2" class="data row0 col2" >1,884,738.56</td>
#       <td id="T_dc54f_row0_col3" class="data row0 col3" >602,049.40</td>
#       <td id="T_dc54f_row0_col4" class="data row0 col4" >3,422,714.78</td>
#     </tr>
#     <tr>
#       <th id="T_dc54f_level0_row1" class="row_heading level0 row1" >B2C</th>
#       <td id="T_dc54f_row1_col0" class="data row1 col0" >729,174.73</td>
#       <td id="T_dc54f_row1_col1" class="data row1 col1" >182,531.47</td>
#       <td id="T_dc54f_row1_col2" class="data row1 col2" >2,248,283.69</td>
#       <td id="T_dc54f_row1_col3" class="data row1 col3" >498,294.88</td>
#       <td id="T_dc54f_row1_col4" class="data row1 col4" >3,658,284.77</td>
#     </tr>
#     <tr>
#       <th id="T_dc54f_level0_row2" class="row_heading level0 row2" >Total</th>
#       <td id="T_dc54f_row2_col0" class="data row2 col0" >1,447,635.95</td>
#       <td id="T_dc54f_row2_col1" class="data row2 col1" >399,997.07</td>
#       <td id="T_dc54f_row2_col2" class="data row2 col2" >4,133,022.25</td>
#       <td id="T_dc54f_row2_col3" class="data row2 col3" >1,100,344.28</td>
#       <td id="T_dc54f_row2_col4" class="data row2 col4" >7,080,999.55</td>
#     </tr>
#   </tbody>
# </table>

# %%
tabla={
      'selector': 'td,th:not(.index_name)',
      'props': 'font-weight:normal; font-family:Arial; text-align:center;background-color:black'
}
indice={
      'selector': '.index_name',
      'props': 'font-weight:normal; font-family:Arial; text-align:rigth;background-color:gray'
}
compra_cliente.set_table_styles([tabla,indice])
# Out:
# <style type="text/css">
# #T_dc54f td {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: black;
# }
# #T_dc54f th:not(.index_name) {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: black;
# }
# #T_dc54f .index_name {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: rigth;
#   background-color: gray;
# }
# </style>
# <table id="T_dc54f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >modo_envio</th>
#       <th id="T_dc54f_level0_col0" class="col_heading level0 col0" >Económica</th>
#       <th id="T_dc54f_level0_col1" class="col_heading level0 col1" >Entrega en 24 horas</th>
#       <th id="T_dc54f_level0_col2" class="col_heading level0 col2" >Entrega estándar</th>
#       <th id="T_dc54f_level0_col3" class="col_heading level0 col3" >Envío rápido</th>
#       <th id="T_dc54f_level0_col4" class="col_heading level0 col4" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >segmento_cliente</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc54f_level0_row0" class="row_heading level0 row0" >B2B</th>
#       <td id="T_dc54f_row0_col0" class="data row0 col0" >718,461.22</td>
#       <td id="T_dc54f_row0_col1" class="data row0 col1" >217,465.60</td>
#       <td id="T_dc54f_row0_col2" class="data row0 col2" >1,884,738.56</td>
#       <td id="T_dc54f_row0_col3" class="data row0 col3" >602,049.40</td>
#       <td id="T_dc54f_row0_col4" class="data row0 col4" >3,422,714.78</td>
#     </tr>
#     <tr>
#       <th id="T_dc54f_level0_row1" class="row_heading level0 row1" >B2C</th>
#       <td id="T_dc54f_row1_col0" class="data row1 col0" >729,174.73</td>
#       <td id="T_dc54f_row1_col1" class="data row1 col1" >182,531.47</td>
#       <td id="T_dc54f_row1_col2" class="data row1 col2" >2,248,283.69</td>
#       <td id="T_dc54f_row1_col3" class="data row1 col3" >498,294.88</td>
#       <td id="T_dc54f_row1_col4" class="data row1 col4" >3,658,284.77</td>
#     </tr>
#     <tr>
#       <th id="T_dc54f_level0_row2" class="row_heading level0 row2" >Total</th>
#       <td id="T_dc54f_row2_col0" class="data row2 col0" >1,447,635.95</td>
#       <td id="T_dc54f_row2_col1" class="data row2 col1" >399,997.07</td>
#       <td id="T_dc54f_row2_col2" class="data row2 col2" >4,133,022.25</td>
#       <td id="T_dc54f_row2_col3" class="data row2 col3" >1,100,344.28</td>
#       <td id="T_dc54f_row2_col4" class="data row2 col4" >7,080,999.55</td>
#     </tr>
#   </tbody>
# </table>

# %%
compra_cliente.set_table_styles({
    'Total':[
        {
            'selector': 'th',
            'props': 'border-top: 2px solid#181818'
        },
        {
            'selector': 'td',
            'props': 'border-top: 2px solid#181818'
        }
    ],
    'B2B':[
        {
            'selector': 'th',
            'props': 'border-top: 1px solid#181818'
        },
        {
            'selector': 'td',
            'props': 'border-top: 1px solid#181818'
        }
    ]
}, overwrite=False, axis=1)
# Out:
# <style type="text/css">
# #T_dc54f td {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: black;
# }
# #T_dc54f th:not(.index_name) {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: black;
# }
# #T_dc54f .index_name {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: rigth;
#   background-color: gray;
# }
# #T_dc54f th.row2 {
#   border-top: 2px solid#181818;
# }
# #T_dc54f td.row2 {
#   border-top: 2px solid#181818;
# }
# #T_dc54f th.row0 {
#   border-top: 1px solid#181818;
# }
# #T_dc54f td.row0 {
#   border-top: 1px solid#181818;
# }
# #T_dc54f th.row2 {
#   border-top: 2px solid#0f0f0f;
# }
# #T_dc54f td.row2 {
#   border-top: 2px solid#181818;
# }
# #T_dc54f th.row0 {
#   border-top: 1px solid#181818;
# }
# #T_dc54f td.row0 {
#   border-top: 1px solid#181818;
# }
# #T_dc54f th.row2 {
#   border-top: 2px solid#181818;
# }
# #T_dc54f td.row2 {
#   border-top: 2px solid#181818;
# }
# #T_dc54f th.row0 {
#   border-top: 1px solid#181818;
# }
# #T_dc54f td.row0 {
#   border-top: 1px solid#181818;
# }
# </style>
# <table id="T_dc54f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >modo_envio</th>
#       <th id="T_dc54f_level0_col0" class="col_heading level0 col0" >Económica</th>
#       <th id="T_dc54f_level0_col1" class="col_heading level0 col1" >Entrega en 24 horas</th>
#       <th id="T_dc54f_level0_col2" class="col_heading level0 col2" >Entrega estándar</th>
#       <th id="T_dc54f_level0_col3" class="col_heading level0 col3" >Envío rápido</th>
#       <th id="T_dc54f_level0_col4" class="col_heading level0 col4" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >segmento_cliente</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc54f_level0_row0" class="row_heading level0 row0" >B2B</th>
#       <td id="T_dc54f_row0_col0" class="data row0 col0" >718,461.22</td>
#       <td id="T_dc54f_row0_col1" class="data row0 col1" >217,465.60</td>
#       <td id="T_dc54f_row0_col2" class="data row0 col2" >1,884,738.56</td>
#       <td id="T_dc54f_row0_col3" class="data row0 col3" >602,049.40</td>
#       <td id="T_dc54f_row0_col4" class="data row0 col4" >3,422,714.78</td>
#     </tr>
#     <tr>
#       <th id="T_dc54f_level0_row1" class="row_heading level0 row1" >B2C</th>
#       <td id="T_dc54f_row1_col0" class="data row1 col0" >729,174.73</td>
#       <td id="T_dc54f_row1_col1" class="data row1 col1" >182,531.47</td>
#       <td id="T_dc54f_row1_col2" class="data row1 col2" >2,248,283.69</td>
#       <td id="T_dc54f_row1_col3" class="data row1 col3" >498,294.88</td>
#       <td id="T_dc54f_row1_col4" class="data row1 col4" >3,658,284.77</td>
#     </tr>
#     <tr>
#       <th id="T_dc54f_level0_row2" class="row_heading level0 row2" >Total</th>
#       <td id="T_dc54f_row2_col0" class="data row2 col0" >1,447,635.95</td>
#       <td id="T_dc54f_row2_col1" class="data row2 col1" >399,997.07</td>
#       <td id="T_dc54f_row2_col2" class="data row2 col2" >4,133,022.25</td>
#       <td id="T_dc54f_row2_col3" class="data row2 col3" >1,100,344.28</td>
#       <td id="T_dc54f_row2_col4" class="data row2 col4" >7,080,999.55</td>
#     </tr>
#   </tbody>
# </table>

# %%
compra_cliente.set_table_styles({
    'Total':[{
        'selector': '.true',
        'props': 'background-color:lightgreen'
    }]
},overwrite=False,axis=0)

colores_columna = pd.DataFrame(['false','true','false'], index=df_cliente['Total'].index, columns=['Total'])
compra_cliente.set_td_classes(colores_columna)
# Out:
# <style type="text/css">
# #T_dc54f td {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: black;
# }
# #T_dc54f th:not(.index_name) {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: center;
#   background-color: black;
# }
# #T_dc54f .index_name {
#   font-weight: normal;
#   font-family: Arial;
#   text-align: rigth;
#   background-color: gray;
# }
# #T_dc54f th.row2 {
#   border-top: 2px solid#181818;
# }
# #T_dc54f td.row2 {
#   border-top: 2px solid#181818;
# }
# #T_dc54f th.row0 {
#   border-top: 1px solid#181818;
# }
# #T_dc54f td.row0 {
#   border-top: 1px solid#181818;
# }
# #T_dc54f th.row2 {
#   border-top: 2px solid#0f0f0f;
# }
# #T_dc54f td.row2 {
#   border-top: 2px solid#181818;
# }
# #T_dc54f th.row0 {
#   border-top: 1px solid#181818;
# }
# #T_dc54f td.row0 {
#   border-top: 1px solid#181818;
# }
# #T_dc54f th.row2 {
#   border-top: 2px solid#181818;
# }
# #T_dc54f td.row2 {
#   border-top: 2px solid#181818;
# }
# #T_dc54f th.row0 {
#   border-top: 1px solid#181818;
# }
# #T_dc54f td.row0 {
#   border-top: 1px solid#181818;
# }
# #T_dc54f .true.col4 {
#   background-color: lightgreen;
# }
# #T_dc54f .true.col4 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_dc54f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >modo_envio</th>
#       <th id="T_dc54f_level0_col0" class="col_heading level0 col0" >Económica</th>
#       <th id="T_dc54f_level0_col1" class="col_heading level0 col1" >Entrega en 24 horas</th>
#       <th id="T_dc54f_level0_col2" class="col_heading level0 col2" >Entrega estándar</th>
#       <th id="T_dc54f_level0_col3" class="col_heading level0 col3" >Envío rápido</th>
#       <th id="T_dc54f_level0_col4" class="col_heading level0 col4" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >segmento_cliente</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc54f_level0_row0" class="row_heading level0 row0" >B2B</th>
#       <td id="T_dc54f_row0_col0" class="data row0 col0" >718,461.22</td>
#       <td id="T_dc54f_row0_col1" class="data row0 col1" >217,465.60</td>
#       <td id="T_dc54f_row0_col2" class="data row0 col2" >1,884,738.56</td>
#       <td id="T_dc54f_row0_col3" class="data row0 col3" >602,049.40</td>
#       <td id="T_dc54f_row0_col4" class="data row0 col4 false" >3,422,714.78</td>
#     </tr>
#     <tr>
#       <th id="T_dc54f_level0_row1" class="row_heading level0 row1" >B2C</th>
#       <td id="T_dc54f_row1_col0" class="data row1 col0" >729,174.73</td>
#       <td id="T_dc54f_row1_col1" class="data row1 col1" >182,531.47</td>
#       <td id="T_dc54f_row1_col2" class="data row1 col2" >2,248,283.69</td>
#       <td id="T_dc54f_row1_col3" class="data row1 col3" >498,294.88</td>
#       <td id="T_dc54f_row1_col4" class="data row1 col4 true" >3,658,284.77</td>
#     </tr>
#     <tr>
#       <th id="T_dc54f_level0_row2" class="row_heading level0 row2" >Total</th>
#       <td id="T_dc54f_row2_col0" class="data row2 col0" >1,447,635.95</td>
#       <td id="T_dc54f_row2_col1" class="data row2 col1" >399,997.07</td>
#       <td id="T_dc54f_row2_col2" class="data row2 col2" >4,133,022.25</td>
#       <td id="T_dc54f_row2_col3" class="data row2 col3" >1,100,344.28</td>
#       <td id="T_dc54f_row2_col4" class="data row2 col4 false" >7,080,999.55</td>
#     </tr>
#   </tbody>
# </table>
